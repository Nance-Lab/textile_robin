# %% [markdown]
# ## Purpose: To view an image from a computers perspective (as an array of numbers)
#
# participate in TEXTILE module 4
#
# date: 7/30/2020

# %% [markdown]
# *step 1: Necessary Imports*

# %%
import numpy as np
from skimage import io

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# *step 2: User Inputs*

# %%
cell_im_location = r"C:\Users\Robin\Downloads\ogd_cells.tif"

# %% [markdown]
# *step 3: Reading in the image*

# %%
cell_im = io.imread(cell_im_location)

# %% [markdown]
# *step 4: Viewing the image*

# %%
cell_im
# Out:
# array([[[ 17,  25,   0],
#         [134, 101,  22],
#         [  0,  65,  16],
#         ...,
#         [251,  16,  26],
#         [268,  11,  32],
#         [261,   0,  19]],
#
#        [[100, 122,   0],
#         [ 31, 136,  16],
#         [ 57,  74,  11],
#         ...,
#         [ 79,  14,   0],
#         [298,   8,  27],
#         [277,  11,  31]],
#
#        [[101,  29,   5],
#         [ 10,  84,   0],
#         [ 35, 111,  11],
#         ...,
#         [240,  22,   7],
#         [181,   0,   9],
#         [256,  15,  29]],
#
#        ...,
#
#        [[ 24,  22,  10],
#         [ 16, 140,   9],
#         [ 70,  78,   2],
#         ...,
#         [103,  11,   7],
#         [  3,   7,   2],
#         [ 33,   0,   4]],
#
#        [[ 17,  80,  10],
#         [  5,  59,   6],
#         [  0, 102,   3],
#         ...,
#         [ 15,   8,   8],
#         [ 31,  11,  14],
#         [137,  15,   0]],
#
#        [[ 62,  27,  18],
#         [ 38,  52,   1],
#         [ 13,  27,   0],
#         ...,
#         [ 42,   0,   9],
#         [ 33,   1,   9],
#         [ 81,   0,   0]]], dtype=uint16)

# %%
cell_im.shape
# Out:
# (512, 512, 3)

# %%
red_cell_im = cell_im[:, :, 0]
green_cell_im = cell_im[:, :, 1]
blue_cell_im = cell_im[:, :, 2]

# %%
plt.imshow(red_cell_im, cmap = 'gray')

# %%
io.imshow(cell_im)
# Out:
# C:\Users\robin\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:75: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
fig, ax = plt.subplots(2, 2, figsize = (8, 8))
ax[0, 0].imshow(red_cell_im, cmap = 'gray')
ax[1, 0].imshow(green_cell_im, cmap = 'gray')
ax[0, 1].imshow(blue_cell_im, cmap = 'gray')
ax[1, 1].imshow(cell_im)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
